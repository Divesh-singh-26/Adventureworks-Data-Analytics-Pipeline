# %% [markdown]
# #  Business Understanding
#
# The Product Categories table contains the main product categories offered by AdventureWorks.
#
# This table is used to classify products into high-level business categories and supports category-level sales analysis.
#
# It will later be connected to the Products table through the ProductSubcategories table.

# %% [markdown]
# # 1. Load the Dataset

# %%
import pandas as pd 
import numpy as np

categories = pd.read_csv("C:/Users/singh/OneDrive/Desktop/AdventureWorks_Analytics/data/raw/AdventureWorks_Product_Categories.csv")

# %% [markdown]
# # 2. Data Profiling

# %%
categories.head()
categories.tail()
# Out:
#    ProductCategoryKey CategoryName
# 0                   1        Bikes
# 1                   2   Components
# 2                   3     Clothing
# 3                   4  Accessories

# %%
categories.shape
# Out:
# (4, 2)

# %% [markdown]
# # 3. Data Quality Assessment
#
# - No missing values found.
# - No duplicate records found.
# - No datatype issues identified.
# - No inconsistent values detected.
# - Column names will be standardized to `snake_case` for consistency across the project.
#
# **Conclusion:** The Product Categories dataset is clean and requires only minor formatting before loading into the ETL pipeline.

# %% [markdown]
# # 4. Data Cleaning

# %%
categories.head()
# Out:
#    ProductCategoryKey CategoryName
# 0                   1        Bikes
# 1                   2   Components
# 2                   3     Clothing
# 3                   4  Accessories

# %%
categories.columns = categories.columns.str.strip()

# %%
categories.columns = [
    'product_category_key',
    'category_name'               
 ]

# %%
categories.dtypes
# Out:
# product_category_key     int64
# category_name           object
# dtype: object

# %%
categories['category_name'] = categories['category_name'].str.strip().str.title()

# %% [markdown]
# # 5. Export Clean Dataset

# %%
categories.to_csv("C:/Users/singh/OneDrive/Desktop/AdventureWorks_Analytics/data/cleaned/categories_clean.csv"
                  ,index=False
 )
